# %%
Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
Flask is the framework or pythonic library by which we can able to create a API . by using this we can 
exicute the pythonic function by using the web URL .

# %%
Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello World!!"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot%20%283%29.png](attachment:Screenshot%20%283%29.png)

# %%
Q3. What is App routing in Flask? Why do we use app routes?

# %%
App routing is a key feature of Flask and is essential for building web applications that are 
flexible, scalable, and easy to maintain.

We use app routing in Flask to define the structure and behavior of our web application. It allows us to
create endpoints that handle specific requests and return appropriate responses.

from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello World!"

# %%
Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation "

@app.route("/")
def company_details():
    return "Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999 "


if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot%20%286%29.png](attachment:Screenshot%20%286%29.png)

# %% [markdown]
# ![Screenshot%20%288%29.png](attachment:Screenshot%20%288%29.png)

# %%
Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.

# %%
In Flask, the url_for() function is used for URL building. It generates a URL for a given 
endpoint with the given method and arguments.


from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'Hello, World!'

@app.route('/user/<username>')
def profile(username):
    return f'Hello, {username}!'

with app.test_request_context():
    print(url_for('index'))
    print(url_for('profile', username='vinay'))
